# %%
def Menu():
    menuList = ["Addition","Substraction","Mutliplication","Division","Power","Exit"]
    option = 1
    for i in menuList:
        print(f"{option}.{i}")
        option = option+1
    choice = int(input("Enter your Choice:"))
    if choice == 1:
        Add()
    elif choice == 2:
        Sub()
    elif choice == 3:
        Multi()
    elif choice == 4:
        Div()
    elif choice == 5:
        Power()
    elif choice == 6:
        quit()
    else: 
        print("Invalid Choice !")
        Menu()


def Add():
    num1 = int(input("Enter First Number :"))
    num2 = int(input("Enter Second Number :"))
    
    print("result :", num1+num2)
    print("Want to Additon Again y/n")
    choice = input("Enter y to Perform Again Enter n To back main Menu :")
    if choice == 'y':
        Add()
    elif choice == 'n':
        Menu()
    else:
        print("Invalid Choice !")

def Sub():
    num1 = int(input("Enter First Number :"))
    num2 = int(input("Enter Second Number :"))
    
    print("result :", num1-num2)
    print("Want to Substraction Again y/n")
    choice = input("Enter y to try Again Enter n To back main Menu :")
    if choice == 'y':
        Sub()
    elif choice == 'n':
        Menu()
    else:
        print("Invalid Choice !")

def Multi():
    num1 = int(input("Enter First Number :"))
    num2 = int(input("Enter Second Number :"))
    
    print("result :", num1*num2)
    print("Want to Mutliply Again y/n")
    choice = input("Enter y to try Again Enter n To back main Menu :")
    if choice == 'y':
        Multi()
    elif choice == 'n':
        Menu()
    else:
        print("Invalid Choice !")
    

def Div():
    num1 = int(input("Enter First Number :"))
    num2 = int(input("Enter Second Number :"))
    
    print("result :", num1/num2)
    print("Want to Divide Again y/n")
    choice = input("Enter y to try Again Enter n To back main Menu :")
    if choice == 'y':
        Div()
    elif choice == 'n':
        Menu()
    else:
        print("Invalid Choice !")

def Power ():
    num1 = int(input("Enter Number :"))
    num2 = int(input("Enter Power :"))
    
    print("result :", num1**num2)
    print("Want to Try Again y/n")
    choice = input("Enter y to try Again Enter n To back main Menu :")
    if choice == 'y':
        Power()
    elif choice == 'n':
        Menu()
    else:
        print("Invalid Choice !")

Menu()
